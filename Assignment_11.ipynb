# %% [markdown]
# # Problem Statement 1
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
# Rename the columns as per the description from this file:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names

# %%
import numpy as np
import pandas as pd
column_names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country']
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",header=None,names=column_names,index_col=False)
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # Task:
# Create a sql db from adult dataset and name it sqladb

# %%
import sqlite3
conn = sqlite3.connect('adult-names.db')
df.to_sql('sqladb',conn,index=False,if_exists='replace')

# %% [markdown]
# 1. Select 10 records from the adult sqladb

# %%
pd.read_sql("SELECT * FROM sqladb LIMIT 10",conn)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# 2. Show me the average hours per week of all men who are working in private sector

# %%
pd.read_sql("SELECT AVG(\"hours-per-week\") FROM sqladb WHERE workclass LIKE '%Private%' LIMIT 10",conn)
# Out:
#    AVG("hours-per-week")
# 0              40.267096

# %% [markdown]
# 3. Show me the frequency table for education, occupation and relationship, separately

# %%
pd.read_sql("SELECT education,COUNT(*) from sqladb GROUP BY education",conn)
# Out:
#         education  COUNT(*)
# 0            10th       933
# 1            11th      1175
# 2            12th       433
# 3         1st-4th       168
# 4         5th-6th       333
# 5         7th-8th       646
# 6             9th       514
# 7      Assoc-acdm      1067
# 8       Assoc-voc      1382
# 9       Bachelors      5355
# 10      Doctorate       413
# 11        HS-grad     10501
# 12        Masters      1723
# 13      Preschool        51
# 14    Prof-school       576
# 15   Some-college      7291

# %%
pd.read_sql("SELECT occupation,COUNT(*) from sqladb GROUP BY occupation",conn)
# Out:
#             occupation  COUNT(*)
# 0                    ?      1843
# 1         Adm-clerical      3770
# 2         Armed-Forces         9
# 3         Craft-repair      4099
# 4      Exec-managerial      4066
# 5      Farming-fishing       994
# 6    Handlers-cleaners      1370
# 7    Machine-op-inspct      2002
# 8        Other-service      3295
# 9      Priv-house-serv       149
# 10      Prof-specialty      4140
# 11     Protective-serv       649
# 12               Sales      3650
# 13        Tech-support       928
# 14    Transport-moving      1597

# %%
pd.read_sql("SELECT relationship,COUNT(*) from sqladb GROUP BY relationship",conn)
# Out:
#       relationship  COUNT(*)
# 0          Husband     13193
# 1    Not-in-family      8305
# 2   Other-relative       981
# 3        Own-child      5068
# 4        Unmarried      3446
# 5             Wife      1568

# %% [markdown]
# 4. Are there any people who are married, working in private sector and having a master’s degree

# %%
pd.read_sql("SELECT * FROM sqladb WHERE \"marital-status\" LIKE '%Married-%' AND workclass LIKE '%Private%' AND education LIKE '%Masters%'",conn)
# Out:
#      age workclass  fnlwgt education  education-num       marital-status  \
# 0     37   Private  284582   Masters             14   Married-civ-spouse
# 1     33   Private  202051   Masters             14   Married-civ-spouse
# 2     76   Private  124191   Masters             14   Married-civ-spouse
# 3     31   Private   99928   Masters             14   Married-civ-spouse
# 4     35   Private  138992   Masters             14   Married-civ-spouse
# ..   ...       ...     ...       ...            ...                  ...
# 535   33   Private  139057   Masters             14   Married-civ-spouse
# 536   34   Private   30673   Masters             14   Married-civ-spouse
# 537   41   Private  201495   Masters             14   Married-civ-spouse
# 538   46   Private   42972   Masters             14   Married-civ-spouse
# 539   53   Private  321865   Masters             14   Married-civ-spouse
#
#            occupation     relationship                 race      sex  \
# ...

# %% [markdown]
# 5. What is the average, minimum and maximum age group for people working in different sectors

# %%
print("Maximum age for each work sector")
print(pd.read_sql("SELECT workclass,MAX(age) FROM sqladb GROUP BY workclass",conn))
print()
print("\nMinimum age for each work sector")
print(pd.read_sql("SELECT workclass,MIN(age) FROM sqladb GROUP BY workclass",conn))
print()
print("\nAverage age for each work sector")
print(pd.read_sql("SELECT workclass,AVG(age) FROM sqladb GROUP BY workclass",conn))
# Out:
# Maximum age for each work sector
#            workclass  MAX(age)
# 0                  ?        90
# 1        Federal-gov        90
# 2          Local-gov        90
# 3       Never-worked        30
# 4            Private        90
# 5       Self-emp-inc        84
# 6   Self-emp-not-inc        90
# 7          State-gov        81
# 8        Without-pay        72
#
#
# Minimum age for each work sector
#            workclass  MIN(age)
# 0                  ?        17
# 1        Federal-gov        17
# 2          Local-gov        17
# 3       Never-worked        17
# 4            Private        17
# 5       Self-emp-inc        17
# 6   Self-emp-not-inc        17
# 7          State-gov        17
# 8        Without-pay        19
#
#
# Average age for each work sector
#            workclass   AVG(age)
# 0                  ?  40.960240
# 1        Federal-gov  42.590625
# 2          Local-gov  41.751075
# 3       Never-worked  20.571429
# 4            Private  36.797585
# ...

# %% [markdown]
# 6. Calculate age distribution by country

# %%
pd.read_sql("SELECT \"native-country\",MIN(AGE),AVG(age),MAX(AGE) FROM sqladb GROUP BY \"native-country\"",conn)
# Out:
#                  native-country  MIN(AGE)   AVG(age)  MAX(AGE)
# 0                             ?        17  38.725557        90
# 1                      Cambodia        18  37.789474        65
# 2                        Canada        17  42.545455        80
# 3                         China        22  42.533333        75
# 4                      Columbia        18  39.711864        75
# 5                          Cuba        21  45.768421        82
# 6            Dominican-Republic        18  37.728571        78
# 7                       Ecuador        21  36.642857        90
# 8                   El-Salvador        17  34.132075        79
# 9                       England        17  41.155556        90
# 10                       France        20  38.965517        64
# 11                      Germany        18  39.255474        74
# 12                       Greece        22  46.206897        65
# 13                    Guatemala        19  32.421875        66
# ...

# %% [markdown]
# 7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capitalgain' and 'capital-loss'

# %%
conn = sqlite3.connect('adult-names.db')
df2=pd.read_sql("SELECT * from sqladb",conn)
df2['Net-Capital-Gain']=df2['capital-gain']-df2['capital-loss']

# %%
df2.to_sql('sqladb',conn,if_exists='replace',index=False)
pd.read_sql("SELECT * from sqladb",conn)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # Problem statement 2:
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

# %%
import pandas as pd
column_names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country']
sqldf = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",header=None,names=column_names,index_col=False)
sqldf.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# Task:
# 1. Create an sqlalchemy engine using a sample from the data set

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
from sqlalchemy.orm import sessionmaker
from sqlalchemy import MetaData

engine = create_engine('sqlite://')
meta = MetaData()
ad_data=Table(
    'adultdata', meta,
    Column('age', Integer),
    Column('workclass', String),
    Column('education', String),
    Column('maritalstatus',String),
    Column('occupation',String)
)
meta.create_all(engine)

conn = engine.connect()

for index,row in sqldf.head(10).iterrows():
    ins = ad_data.insert().values(age=row.age, workclass=row.workclass, education=row.education, maritalstatus=row['marital-status'],occupation=row.occupation)
    conn.execute(ins)
    
for row in conn.execute(ad_data.select()):
    print(row)
# Out:
# (39, ' State-gov', ' Bachelors', ' Never-married', ' Adm-clerical')
# (50, ' Self-emp-not-inc', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')
# (38, ' Private', ' HS-grad', ' Divorced', ' Handlers-cleaners')
# (53, ' Private', ' 11th', ' Married-civ-spouse', ' Handlers-cleaners')
# (28, ' Private', ' Bachelors', ' Married-civ-spouse', ' Prof-specialty')
# (37, ' Private', ' Masters', ' Married-civ-spouse', ' Exec-managerial')
# (49, ' Private', ' 9th', ' Married-spouse-absent', ' Other-service')
# (52, ' Self-emp-not-inc', ' HS-grad', ' Married-civ-spouse', ' Exec-managerial')
# (31, ' Private', ' Masters', ' Never-married', ' Prof-specialty')
# (42, ' Private', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')

# %% [markdown]
# 2. Write two basic update queries

# %%
upd = ad_data.update().where(ad_data.c.maritalstatus == ' Never-married').values(maritalstatus='Bachelor')
conn.execute(upd) # Updating marital-status for Never-married to Bachelor
upd2 = ad_data.update().where(ad_data.c.workclass != ' Private').values(workclass='Public')
conn.execute(upd2) # Updating all workclass which are not Private as Public

for row in conn.execute(ad_data.select()):
    print(row)
# Out:
# (39, 'Public', ' Bachelors', 'Bachelor', ' Adm-clerical')
# (50, 'Public', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')
# (38, ' Private', ' HS-grad', ' Divorced', ' Handlers-cleaners')
# (53, ' Private', ' 11th', ' Married-civ-spouse', ' Handlers-cleaners')
# (28, ' Private', ' Bachelors', ' Married-civ-spouse', ' Prof-specialty')
# (37, ' Private', ' Masters', ' Married-civ-spouse', ' Exec-managerial')
# (49, ' Private', ' 9th', ' Married-spouse-absent', ' Other-service')
# (52, 'Public', ' HS-grad', ' Married-civ-spouse', ' Exec-managerial')
# (31, ' Private', ' Masters', 'Bachelor', ' Prof-specialty')
# (42, ' Private', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')

# %% [markdown]
# 3. Write two delete queries

# %%
del1 = ad_data.delete().where(ad_data.c.age > 50)
conn.execute(del1)
s = ad_data.select()
print("Result after deleting records of adults aged over 50:",conn.execute(s).fetchall())

del2 = ad_data.delete().where(ad_data.c.workclass != ' Private')
conn.execute(del2)
s = ad_data.select()
print()
print("Result after deleting records of adults not working in Private class:",conn.execute(s).fetchall())
# Out:
# Result after deleting records of adults aged over 50: [(38, ' Private', ' HS-grad', ' Divorced', ' Handlers-cleaners'), (28, ' Private', ' Bachelors', ' Married-civ-spouse', ' Prof-specialty'), (37, ' Private', ' Masters', ' Married-civ-spouse', ' Exec-managerial'), (49, ' Private', ' 9th', ' Married-spouse-absent', ' Other-service'), (31, ' Private', ' Masters', 'Bachelor', ' Prof-specialty'), (42, ' Private', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')]
#
# Result after deleting records of adults not working in Private class: [(38, ' Private', ' HS-grad', ' Divorced', ' Handlers-cleaners'), (28, ' Private', ' Bachelors', ' Married-civ-spouse', ' Prof-specialty'), (37, ' Private', ' Masters', ' Married-civ-spouse', ' Exec-managerial'), (49, ' Private', ' 9th', ' Married-spouse-absent', ' Other-service'), (31, ' Private', ' Masters', 'Bachelor', ' Prof-specialty'), (42, ' Private', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')]

# %% [markdown]
# 4. Write two filter queries

# %%
s = ad_data.select().where(ad_data.c.age > 40)
print("Fetching all adult details whose age is greater than 40:",conn.execute(s).fetchall())
print()
s2 = ad_data.select().where(ad_data.c.education == ' Masters')
print("Fetching all adult details whose education is 'Masters':",conn.execute(s2).fetchall())
# Out:
# Fetching all adult details whose age is greater than 40: [(49, ' Private', ' 9th', ' Married-spouse-absent', ' Other-service'), (42, ' Private', ' Bachelors', ' Married-civ-spouse', ' Exec-managerial')]
#
# Fetching all adult details whose education is 'Masters': [(37, ' Private', ' Masters', ' Married-civ-spouse', ' Exec-managerial'), (31, ' Private', ' Masters', 'Bachelor', ' Prof-specialty')]

# %% [markdown]
# 5. Write two function queries

# %%
from sqlalchemy.sql import func,select
print("Max age in all records is:",conn.execute(select([func.max(ad_data.c.age)])).fetchone())
print("Min age in all records is:",conn.execute(select([func.min(ad_data.c.age)])).fetchone())
# Out:
# Max age in all records is: (49,)
# Min age in all records is: (28,)
